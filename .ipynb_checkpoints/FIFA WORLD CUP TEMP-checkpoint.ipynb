# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import gmaps
import os
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup as soup

# Import API key
from config import key
from config import WeatherKey



data = pd.read_csv('Resources/matYearCountry.csv')

data.head()

# data.to_csv("countries_temp_data.csv", encoding="utf-8", index=False)
# Out:
#    year     Åland  Afghanistan     Africa    Albania    Algeria  \
# 0  2000  7.283333    15.497833  24.588083  13.746583  24.032250
# 1  2001  6.401500    15.778083  24.841167  13.690417  24.724417
# 2  2002  6.801083    15.537667  24.961333  13.559917  24.263000
# 3  2003  6.323417    14.916000  25.025583  13.626583  24.393667
# 4  2004  6.518667    15.770917  24.895917  13.258167  23.916000
#
#    American Samoa    Andorra     Angola   Anguilla  ...   Korea Republic  \
# 0       27.219833  12.311917  22.360667  27.052750  ...             11.5
# 1       27.227583  12.216083  22.502917  27.408500  ...              NaN
# 2       27.537917  12.319583  22.925500  27.538250  ...              NaN
# 3       27.264833  12.900667  23.066583  27.677417  ...              NaN
# 4       27.281167  12.043000  22.572833  27.334000  ...              NaN
#
#    Republic of Ireland',   China PR   China PR.1  Trinidad and Tobago  \
# 0                    9.3       6.95         6.95                25.75
# 1                    NaN        NaN          NaN                  NaN
# 2                    NaN        NaN          NaN                  NaN
# 3                    NaN        NaN          NaN                  NaN
# 4                    NaN        NaN          NaN                  NaN
#
#    Serbia and Montenegro  Ivory Coast   IR Iran  Bosnia and Herzegovina  \
# 0                  10.55        26.35     17.25                    9.85
# 1                    NaN          NaN       NaN                     NaN
# 2                    NaN          NaN       NaN                     NaN
# 3                    NaN          NaN       NaN                     NaN
# 4                    NaN          NaN       NaN                     NaN
#
#     Dutch East Indies
# 0               23.65
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 266 columns]

# %%
data2 = data[['France',
 'Romania',
 'Argentina',
 'Chile',
 'Uruguay',
 'Brazil',
 'Paraguay',
 'Austria',
 'Hungary',
 'Switzerland',
 'Sweden',
 'Germany',
 'Spain',
 'Italy',
 'Cuba',
 'Turkey',
 'Mexico',
 'Portugal',
 'Peru',
 'Belgium',
 'Bulgaria',
 'Poland',
 'Australia',
 'Netherlands',
 'Haiti',
 'Tunisia',
 'Algeria',
 'Honduras',
 'Canada',
 'Morocco',
 'Iraq',
 'Denmark',
 'United Arab Emirates',
 'Costa Rica',
 'Cameroon',
 'Colombia',
 'Norway',
 'Nigeria',
 'Saudi Arabia',
 'Bolivia',
 'Russia',
 'Greece',
 'Jamaica',
 'South Africa',
 'Japan',
 'Croatia',
 'Senegal',
 'Slovenia',
 'Ecuador',
 'Angola',
 'Czech Republic',
 'Togo',
 'Iran',
 'Ghana',
 'Ukraine',
 'Serbia',
 'New Zealand',
 'Slovakia',
 'Mexico',
 'Belgium',
 'Brazil',
 'Peru',
 'France',
 'Bolivia',
 'Paraguay',
 'Romania',
 'Chile',
 'Argentina',
 'Egypt',
 'Netherlands',
 'Switzerland',
 'Sweden',
 'Spain',
 'Hungary',
 'Austria',
 'Germany',
 'Norway',
 'Poland',
 'Cuba',
 'Italy',
 'Turkey',
 'Uruguay',
 'Colombia',
 'Bulgaria',
 'Portugal',
 'Israel',
 'Morocco',
 'El Salvador',
 'Australia',
 'Haiti',
 'Tunisia',
 'Iran',
 'Cameroon',
 'New Zealand',
 'Algeria',
 'Honduras',
 'Kuwait',
 'Iraq',
 'Denmark',
 'Canada',
 'United Arab Emirates',
 'Costa Rica',
 'Saudi Arabia',
 'Russia',
 'Greece',
 'Nigeria',
 'South Africa',
 'Japan',
 'Croatia',
 'Jamaica',
 'Senegal',
 'Slovenia',
 'Ecuador',
 'Czech Republic',
 'Ghana',
 'Togo',
 'Ukraine',
 'Angola',
 'Slovakia',
 'Serbia']]

data2.head()
# Out:
#       France    Romania  Argentina      Chile    Uruguay     Brazil  \
# 0  13.967333  10.472250  14.750500   9.564083  17.756750  25.196500
# 1  13.696500   9.638583  15.370417   9.819667  18.574250  25.504417
# 2  14.048167  10.392667  15.183750   9.742417  17.993917  25.800333
# 3  14.337917   9.340167  15.518333  10.078417  17.604667  25.621000
# 4  13.664083   9.558167  15.442167  10.205833  18.060833  25.496500
#
#     Paraguay   Austria    Hungary  Switzerland  ...    Senegal   Slovenia  \
# 0  23.626083  8.084917  11.700333     8.562667  ...  28.526083  11.590583
# 1  24.288250  7.188917  10.523750     7.979750  ...  28.936333  10.894667
# 2  24.759000  7.915250  11.432083     8.484833  ...  28.978167  11.337250
# 3  24.263833  7.509333  10.597917     8.669750  ...  28.704167  11.009667
# 4  23.804500  6.906083  10.311500     7.846083  ...  28.852083  10.241250
#
#      Ecuador  Czech Republic      Ghana       Togo   Ukraine     Angola  \
# 0  22.026000        9.659000  27.245917  27.442417  9.316333  22.360667
# 1  22.236083        8.378833  27.278750  27.410500  8.938667  22.502917
# 2  22.763667        9.203667  27.401083  27.497250  9.377167  22.925500
# 3  22.668333        8.871333  27.533500  27.666750  8.219667  23.066583
# 4  22.647917        8.445917  27.415833  27.534917  8.850500  22.572833
#
#    Slovakia     Serbia
# 0  9.482000  11.791000
# 1  8.307750  10.913167
# 2  9.136417  11.413417
# 3  8.487083  10.795500
# 4  8.145583  10.616500
#
# [5 rows x 120 columns]

# %%
mean = data2.mean().astype(int)

temp_data = pd.DataFrame(mean)

temp_data = temp_data.rename(columns={0:"Average Temperature"})

# temp_data.columns = ['Countries', 'Average Temperature']

temp_data

# temp_data.to_csv("temp_data.csv", encoding="utf-8", index=False)

read_data = pd.read_csv('Resources/temp_data.csv')

read_data.drop_duplicates(['Countries'], keep='last')

# read_data
# Out:
#     Countries  Average Temperature
# 58     Mexico                   21
# 59    Belgium                   10
# 60     Brazil                   25
# 61       Peru                   20
# 62     France                   13
# ..        ...                  ...
# 115      Togo                   27
# 116   Ukraine                    9
# 117    Angola                   22
# 118  Slovakia                    8
# 119    Serbia                   11
#
# [62 rows x 2 columns]

# %%
data3 = pd.read_csv("Resources/new_temp.csv")

data3['Average Temperature']=data3['Average Temperature'].astype(float)

# data3

# %%
merged = pd.concat([read_data,data3])

merged.drop_duplicates(subset= ["Countries"], keep = False)

merged
# Out:
#                  Countries  Average Temperature
# 0                   France                13.00
# 1                  Romania                10.00
# 2                Argentina                15.00
# 3                    Chile                 9.00
# 4                  Uruguay                17.00
# ..                     ...                  ...
# 16   Serbia and Montenegro                10.55
# 17             Ivory Coast                26.35
# 18                 IR Iran                17.25
# 19  Bosnia and Herzegovina                 9.85
# 20       Dutch East Indies                23.65
#
# [141 rows x 2 columns]

# %%
finilized_temp = pd.read_csv("Resources/temp_location.csv" ,encoding='utf-8')

finilized_temp
# Out:
#      Countries  Average Temperature   Latitude  Longtitude
# 0      Algeria                24.00  28.033886    1.659626
# 1       Angola                22.00 -11.202692   17.873887
# 2    Argentina                15.00 -38.416097  -63.616672
# 3    Australia                22.00 -25.274398  133.775136
# 4      Austria                 7.00  47.516231   14.550072
# ..         ...                  ...        ...         ...
# 71     Uruguay                17.00 -32.522779  -55.765835
# 72         USA                 8.55  37.090240  -95.712891
# 73       Wales                 8.45  55.378051   -3.435973
# 74  Yugoslavia                 8.90  44.016521   21.005859
# 75       Zaire                21.40  -1.940278   29.873888
#
# [76 rows x 4 columns]

# %%
cold = finilized_temp.loc[finilized_temp['Average Temperature'] <= 8]
len(cold)
# Out:
# 11

# %%
warm = finilized_temp.loc[(finilized_temp['Average Temperature'] >= 16) & (finilized_temp['Average Temperature'] <= 25)]
len(warm)
# Out:
# 23

# %%
hot = finilized_temp.loc[finilized_temp['Average Temperature'] >= 25]
len(hot)
# Out:
# 18

# %%
mild = finilized_temp.loc[(finilized_temp['Average Temperature'] >= 9) & (finilized_temp['Average Temperature'] <= 15)]
len(mild)
# Out:
# 24

# %%
numbers = [11, 23, 18, 24]

explode = (0.1,0.1,0.1, 0.1)

labels = ["Cold Climate(8 C and below)","Warm Climate (Between 16 C and 25 C)", "Hot Climate (25 C and above)", "Mild Climate (Between 9 C and 15 C)"]

colors = ["lightblue","orange", "red", "pink"]

fig=plt.pie(numbers, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)

plt.axis("equal")

plt.savefig("Climate Pie Char.png")

plt.show()

# %%
locations = finilized_temp[["Latitude", "Longtitude"]]

rating = finilized_temp["Average Temperature"].astype(float)

# %%
#Basic Google heat map for relative temps by host country

data = pd.read_csv('Resources/temp_location.csv')

hosts = pd.read_csv('hosts2.csv')


hosts = pd.merge(hosts, data, on='Countries', how='left')
locations = hosts[['Latitude', 'Longtitude']]
weights = hosts['Average Temperature']
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights.abs()))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
team_points = pd.read_csv("Resources/Team_Points.csv" ,encoding='utf-8')

# renamed_t_points = team_points.rename(columns={"Team":"Countries"})

team_points.head()
# Out:
#    Countries  Number of Games Played  Number of Wins  Number of Losses  \
# 0    Algeria                      13               3                 7
# 1     Angola                       3               0                 1
# 2  Argentina                      77              42                21
# 3  Australia                      13               2                 8
# 4    Austria                      29              12                13
#
#    Number of Draws  Points  Average Points per Game
# 0                3       9                    0.692
# 1                2       2                    0.667
# 2               14      98                    1.273
# 3                3       7                    0.538
# 4                4      28                    0.966

# %%
merge_table2 = pd.merge(finilized_temp, team_points, on="Countries")

merge_table2.head()

# merge_table2.to_csv("merge_table2.csv", encoding="utf-8", index=False)
# Out:
#    Countries  Average Temperature   Latitude  Longtitude  \
# 0    Algeria                 24.0  28.033886    1.659626
# 1     Angola                 22.0 -11.202692   17.873887
# 2  Argentina                 15.0 -38.416097  -63.616672
# 3  Australia                 22.0 -25.274398  133.775136
# 4    Austria                  7.0  47.516231   14.550072
#
#    Number of Games Played  Number of Wins  Number of Losses  Number of Draws  \
# 0                      13               3                 7                3
# 1                       3               0                 1                2
# 2                      77              42                21               14
# 3                      13               2                 8                3
# 4                      29              12                13                4
#
#    Points  Average Points per Game
# 0       9                    0.692
# 1       2                    0.667
# 2      98                    1.273
# 3       7                    0.538
# 4      28                    0.966

# %%
print(len(merge_table2))
print(len(cold))
print(len(warm))
print(len(hot))
print(len(mild))
# Out:
# 76
# 11
# 23
# 18
# 24

# %%
cold = merge_table2.loc[merge_table2['Average Temperature'] <= 8]

cold["Points"].sum()
# Out:
# 235

# %%
warm = merge_table2.loc[(merge_table2['Average Temperature'] >= 16) & (merge_table2['Average Temperature'] <= 25)]

warm["Points"].sum()
# Out:
# 379

# %%
hot = merge_table2.loc[merge_table2['Average Temperature'] >= 25]

hot["Points"].sum()
# Out:
# 255

# %%
mild = merge_table2.loc[(merge_table2['Average Temperature'] >= 9) & (merge_table2['Average Temperature'] <= 15)]

mild["Points"].sum()
# Out:
# 840

# %%
points_comp = [{"Climates": "Warm Climate", "Total Points": 379},
                {"Climates": "Cold Climate", "Total Points": 235},
              {"Climates": "Hot Climate", "Total Points": 255},
              {"Climates": "Mild Climate", "Total Points": 840}]


df_points_comp = pd.DataFrame(points_comp)

df_points_comp.set_index('Climates', inplace=True)

df_points_comp
# Out:
#               Total Points
# Climates
# Warm Climate           379
# Cold Climate           235
# Hot Climate            255
# Mild Climate           840

# %%
bar_char = df_points_comp.plot(kind='bar', title ="Point Comparitions",figsize=(10,7),legend=True, fontsize=10)

bar_char.set_xlabel("Climates",fontsize=12)

bar_char.set_ylabel("Total Points",fontsize=12)

plt.savefig("Climate Bar Char.png")

# %%
# Create file
file = "worldCupWinners.csv"
f = open(file, "w")

# Get the url that we would like to scrape
url = "https://en.wikipedia.org/wiki/FIFA_World_Cup"
response = requests.get(url,headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'})
page = soup(response.content, "html.parser")

# Find the table we would like to turn into a csv
table = page.find("table", {"style": "text-align:center;width:100%; font-size:90%;"})

# This creates a a list of webelements we can loop through
tableRows = table.findAll("tr")

# %%
# Creates headers for csv file.
headers = "Year,Hosts,Champions,Runners-up,Third place,Fourth place,No. of Teams"
f.write(headers)

# Loops through the list of tablerows
for tr in tableRows:

    # Creates a list of elements in the iterated tablerow
    td = tr.findAll('td')

    # This iterates through each cell to place them in the file.
    for i in td:
        
        #Formats i to not have errors
        i = i.text.strip()
        i = i.replace("\n", "")
        i = i.replace(",", " ")
        
        # Writes in cell
        f.write(str(i))
        
        #Changes cells
        f.write(",")
    
    # Changes rows
    f.write("\n")

# Closes csv
f.close()

# %%
# This gives us three duplicate dataframes
temp_data = pd.read_csv("Resources/temp_location.csv")
temp_data2 = temp_data
temp_data3 = temp_data

# Drops the columns we don't need
temp_data = temp_data.drop('Latitude', 1)
temp_data = temp_data.drop('Longtitude', 1)

temp_data2 = temp_data2.drop('Latitude', 1)
temp_data2 = temp_data2.drop('Longtitude', 1)

temp_data3 = temp_data3.drop('Latitude', 1)
temp_data3 = temp_data3.drop('Longtitude', 1)

# Rename columns to be able to merge the three columns we need.
temp_data = temp_data.rename(columns={"Countries": "Home Team Name"})
temp_data2 = temp_data2.rename(columns={"Countries": "Away Team Name"})
temp_data3 = temp_data3.rename(columns={"Countries": "Winning Team"})

# These are the columns we are adding to our WC_DF dataframe
temp_data = temp_data.rename(columns={"Average Temperature": "Home Team Average Temperature"})
temp_data2 = temp_data2.rename(columns={"Average Temperature": "Away Team Average Temperature"})
temp_data3 = temp_data3.rename(columns={"Average Temperature": "Winning Team Average Temperature"})

temp_data.head()
# Out:
#   Home Team Name  Home Team Average Temperature
# 0        Algeria                           24.0
# 1         Angola                           22.0
# 2      Argentina                           15.0
# 3      Australia                           22.0
# 4        Austria                            7.0

# %%
# Get the main dataframe
WC_df = pd.read_csv("Resources/WorldCupMatches_HG.csv")

# Creates list to loop through to get weather data
cities = WC_df["City"].tolist()

# Url for the API
url = "https://api.worldweatheronline.com/premium/v1/past-weather.ashx"

# list to append weather data
tempMax = []

# Loop through cities list
for city in cities:        
    
    # Url to get request
    query_url = (f"https://api.worldweatheronline.com/premium/v1/past-weather.ashx?q={city}&date=2019-07-13&enddate=2019-07-14&format=json&key={WeatherKey}")
    
    # Gets response
    response = requests.get(query_url).json()
    data = response
    
    # Appends temperatures to tempMax list
    try:
        tempMax.append(data["data"]["weather"][0]["maxtempC"])
        print(f"{city} is being processed now.")
    except KeyError:
        tempMax.append(None)
        print(f"{city} is being skipped")
# Out:
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Montevideo  is being processed now.
# Turin  is being processed now.
# Naples  is being processed now.
# Milan  is being processed now.
# Bologna  is being processed now.
# Florence  is being processed now.
# Genoa  is being processed now.
# Rome  is being processed now.
# Trieste  is being processed now.
# Turin  is being processed now.
# Milan  is being processed now.
# Florence  is being processed now.
# Bologna  is being processed now.
# Florence  is being processed now.
# Milan  is being processed now.
# Rome  is being processed now.
# Naples  is being processed now.
# Rome  is being processed now.
# Paris  is being processed now.
# Reims  is being processed now.
# Colombes  is being processed now.
# Toulouse  is being processed now.
# Marseilles  is being processed now.
# Strasbourg  is being processed now.
# Le Havre  is being processed now.
# Toulouse  is being processed now.
# Paris  is being processed now.
# Bordeaux  is being processed now.
# Busan  is being processed now.
# Kobe  is being processed now.
# Suwon  is being processed now.
# Ibaraki  is being processed now.
# Daegu  is being processed now.
# Saitama  is being processed now.
# Busan  is being processed now.
# Kobe  is being processed now.
# Sapporo  is being processed now.
# Jeonju  is being processed now.
# Daegu  is being processed now.
# Jeju  is being processed now.
# Ibaraki  is being processed now.
# Incheon  is being processed now.
# Yokohama  is being processed now.
# Rifu  is being processed now.
# Daegu  is being processed now.
# Jeonju  is being processed now.
# Oita  is being processed now.
# Incheon  is being processed now.
# Suwon  is being processed now.
# Yokohama  is being processed now.
# Shizuoka  is being processed now.
# Rifu  is being processed now.
# Osaka  is being processed now.
# Jeju  is being processed now.
# Daejeon  is being processed now.
# Suwon  is being processed now.
# Seoul  is being processed now.
# Yokohama  is being processed now.
# Oita  is being processed now.
# Osaka  is being processed now.
# Incheon  is being processed now.
# Daejeon  is being processed now.
# Shizuoka  is being processed now.
# Niigata  is being processed now.
# Jeju  is being processed now.
# Suwon  is being processed now.
# Oita  is being processed now.
# Kobe  is being processed now.
# Jeonju  is being processed now.
# Rifu  is being processed now.
# Daejeon  is being processed now.
# Shizuoka  is being processed now.
# Ulsan  is being processed now.
# Osaka  is being processed now.
# Gwangju  is being processed now.
# Seoul  is being processed now.
# Saitama  is being processed now.
# Daegu  is being processed now.
# Yokohama  is being processed now.
# Munich  is being processed now.
# Gelsenkirchen  is being processed now.
# Frankfurt/Main  is being processed now.
# Dortmund  is being processed now.
# Hamburg  is being processed now.
# Leipzig  is being processed now.
# Nuremberg  is being processed now.
# Cologne  is being processed now.
# Kaiserslautern  is being processed now.
# Gelsenkirchen  is being processed now.
# Hanover  is being processed now.
# Frankfurt/Main  is being processed now.
# Stuttgart  is being processed now.
# Berlin  is being processed now.
# Leipzig  is being processed now.
# Munich  is being processed now.
# Dortmund  is being processed now.
# Hamburg  is being processed now.
# Nuremberg  is being processed now.
# Berlin  is being processed now.
# Gelsenkirchen  is being processed now.
# Stuttgart  is being processed now.
# Hanover  is being processed now.
# Frankfurt/Main  is being processed now.
# Cologne  is being processed now.
# Kaiserslautern  is being processed now.
# Nuremberg  is being processed now.
# Munich  is being processed now.
# Leipzig  is being processed now.
# Dortmund  is being processed now.
# Hamburg  is being processed now.
# Stuttgart  is being processed now.
# Berlin  is being processed now.
# Hanover  is being processed now.
# Cologne  is being processed now.
# Kaiserslautern  is being processed now.
# Leipzig  is being processed now.
# Gelsenkirchen  is being processed now.
# Frankfurt/Main  is being processed now.
# Munich  is being processed now.
# Hamburg  is being processed now.
# Nuremberg  is being processed now.
# Dortmund  is being processed now.
# Stuttgart  is being processed now.
# Berlin  is being processed now.
# Kaiserslautern  is being processed now.
# Cologne  is being processed now.
# Hanover  is being processed now.
# Munich  is being processed now.
# Leipzig  is being processed now.
# Stuttgart  is being processed now.
# Nuremberg  is being processed now.
# Kaiserslautern  is being processed now.
# Cologne  is being processed now.
# Dortmund  is being processed now.
# Hanover  is being processed now.
# Berlin  is being processed now.
# Hamburg  is being processed now.
# Recife  is being processed now.
# Salvador  is being processed now.
# Curitiba  is being processed now.
# Belo Horizonte  is being processed now.
# Fortaleza  is being processed now.
# Cuiaba  is being processed now.
# Rio De Janeiro  is being processed now.
# Porto Alegre  is being processed now.
# Manaus  is being processed now.
# Curitiba  is being processed now.
# Sao Paulo  is being processed now.
# Brasilia  is being processed now.
# Recife  is being processed now.
# Natal  is being processed now.
# Belo Horizonte  is being processed now.
# Cuiaba  is being processed now.
# Fortaleza  is being processed now.
# Porto Alegre  is being processed now.
# Salvador  is being processed now.
# Manaus  is being processed now.
# Rio De Janeiro  is being processed now.
# Recife  is being processed now.
# Brasilia  is being processed now.
# Sao Paulo  is being processed now.
# Curitiba  is being processed now.
# Rio De Janeiro  is being processed now.
# Fortaleza  is being processed now.
# Salvador  is being processed now.
# Belo Horizonte  is being processed now.
# Rio De Janeiro  is being processed now.
# Recife  is being processed now.
# Brasilia  is being processed now.
# Porto Alegre  is being processed now.
# Sao Paulo  is being processed now.
# Fortaleza  is being processed now.
# Brasilia  is being processed now.
# Salvador  is being processed now.
# Belo Horizonte  is being processed now.
# Sao Paulo  is being processed now.
# Brasilia  is being processed now.
# Rio De Janeiro  is being processed now.

# %%
# Creates City Temperature column
WC_df["City Temperature"] = tempMax

# Merges Home team temperature
df = WC_df.merge(temp_data, on='Home Team Name', how='outer')

# Merges Away team temperature
df = df.merge(temp_data2, on='Away Team Name', how='outer')

# Merges Winning team temperature
df = df.merge(temp_data3, on='Winning Team', how='outer')
df.to_csv("WorldCupMatchesUpdate.csv")
df.head()
# Out:
#      Year              Datetime                  Stage          Stadium  \
# 0  1930.0  13 Jul 1930 - 15:00                 Group 1          Pocitos
# 1  1954.0  19 Jun 1954 - 17:10                 Group 1       Charmilles
# 2  1938.0  05 Jun 1938 - 17:00             First round  Stade Olympique
# 3  1986.0  28 Jun 1986 - 12:00   Match for third place       Cuauhtemoc
# 4  1958.0  08 Jun 1958 - 19:00                 Group 2    Idrottsparken
#
#           City Home Team Name  Home Team Goals  Away Team Goals  \
# 0  Montevideo          France              4.0              1.0
# 1      Geneva          France              3.0              2.0
# 2    Colombes          France              3.0              1.0
# 3      Puebla          France              4.0              2.0
# 4  Norrk�Ping          France              7.0              3.0
#
#   Away Team Name Results Winning Team                Win conditions  MatchID  \
# 0         Mexico       H       France                                 1096.0
# 1         Mexico       H       France                                 1275.0
# 2        Belgium       H       France                                 1146.0
# 3        Belgium       H       France  France win after extra time     422.0
# 4       Paraguay       H       France                                 1386.0
#
#   Home Team Initials Away Team Initials City Temperature  \
# 0                FRA                MEX               11
# 1                FRA                MEX               23
# 2                FRA                BEL               25
# 3                FRA                BEL               24
# 4                FRA                PAR               29
#
#    Home Team Average Temperature  Away Team Average Temperature  \
# 0                           13.0                           21.0
# 1                           13.0                           21.0
# 2                           13.0                           10.0
# 3                           13.0                           10.0
# 4                           13.0                           23.0
#
#    Winning Team Average Temperature
# 0                              13.0
# 1                              13.0
# 2                              13.0
# 3                              13.0
# 4                              13.0
