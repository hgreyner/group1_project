# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

WC_csv ="WorldCupMatchesUpdate.csv"

WC_df = pd.read_csv(WC_csv)

WC_df.head(30)
# Out:
#     Unnamed: 0    Year              Datetime                  Stage  \
# 0            0  1930.0  13 Jul 1930 - 15:00                 Group 1
# 1            1  1954.0  19 Jun 1954 - 17:10                 Group 1
# 2            2  1938.0  05 Jun 1938 - 17:00             First round
# 3            3  1986.0  28 Jun 1986 - 12:00   Match for third place
# 4            4  1958.0  08 Jun 1958 - 19:00                 Group 2
# 5            5  1998.0  28 Jun 1998 - 16:30             Round of 16
# 6            6  1958.0  15 Jun 1958 - 19:00                 Group 2
# 7            7  1958.0  19 Jun 1958 - 19:00          Quarter-finals
# 8            8  1982.0  04 Jul 1982 - 17:15                 Group 4
# 9            9  1958.0  28 Jun 1958 - 17:00   Match for third place
# 10          10  1978.0  10 Jun 1978 - 15:10                 Group 1
# 11          11  1982.0  21 Jun 1982 - 17:15                 Group 4
# 12          12  1998.0  12 Jun 1998 - 21:00                 Group C
# 13          13  1998.0  18 Jun 1998 - 21:00                 Group C
# 14          14  1998.0  24 Jun 1998 - 16:00                 Group C
# 15          15  1998.0  08 Jul 1998 - 21:00             Semi-finals
# 16          16  2014.0  15 Jun 2014 - 16:00                 Group E
# 17          17  2014.0  30 Jun 2014 - 13:00             Round of 16
# 18          18  1998.0  12 Jul 1998 - 21:00                   Final
# 19          19  2006.0  01 Jul 2006 - 21:00          Quarter-finals
# 20          20  1982.0  28 Jun 1982 - 17:15                 Group 4
# 21          21  1986.0  09 Jun 1986 - 12:00                 Group C
# 22          22  2014.0  20 Jun 2014 - 16:00                 Group E
# 23          23  2006.0  27 Jun 2006 - 21:00             Round of 16
# 24          24  1986.0  17 Jun 1986 - 12:00             Round of 16
# 25          25  2006.0  05 Jul 2006 - 21:00             Semi-finals
# 26          26  1986.0  01 Jun 1986 - 16:00                 Group C
# 27          27  2006.0  23 Jun 2006 - 21:00                 Group G
# 28          28  1966.0  13 Jul 1966 - 19:30                 Group 1
# 29          29  1966.0  19 Jul 1966 - 16:30                 Group 1
#
#                               Stadium             City Home Team Name  \
# 0                             Pocitos      Montevideo          France
# 1                          Charmilles          Geneva          France
# 2                     Stade Olympique        Colombes          France
# 3                          Cuauhtemoc          Puebla          France
# 4                       Idrottsparken      Norrk�Ping          France
# 5                Stade Felix Bollaert            Lens          France
# 6                          Eyravallen          Orebro          France
# 7                       Idrottsparken      Norrk�Ping          France
# 8                    Vicente Calderon          Madrid          France
# 9                          Nya Ullevi      Gothenburg          France
# 10         Estadio Jos� Mar�a Minella   Mar Del Plata          France
# 11                      Jose Zorrilla      Valladolid          France
# 12                    Stade V�lodrome      Marseilles          France
# 13                    Stade de France     Saint-Denis          France
# 14                   Stade de Gerland            Lyon          France
# 15                    Stade de France     Saint-Denis          France
# 16                  Estadio Beira-Rio    Porto Alegre          France
# 17                   Estadio Nacional        Brasilia          France
# 18                    Stade de France     Saint-Denis          Brazil
# 19  FIFA World Cup Stadium, Frankfurt  Frankfurt/Main          Brazil
# 20                   Vicente Calderon          Madrid         Austria
# 21            Nou Camp - Estadio Le�n            Leon         Hungary
# 22                   Arena Fonte Nova        Salvador     Switzerland
# 23    FIFA World Cup Stadium, Hanover         Hanover           Spain
# 24     Estadio Ol�mpico Universitario     Mexico City           Italy
# 25     FIFA World Cup Stadium, Munich          Munich        Portugal
# 26            Nou Camp - Estadio Le�n            Leon          Canada
# 27    FIFA World Cup Stadium, Cologne         Cologne            Togo
# 28                    Wembley Stadium          London          France
# 29                    Wembley Stadium          London         Uruguay
#
#     Home Team Goals  Away Team Goals    Away Team Name Results Winning Team  \
# 0               4.0              1.0            Mexico       H       France
# 1               3.0              2.0            Mexico       H       France
# 2               3.0              1.0           Belgium       H       France
# 3               4.0              2.0           Belgium       H       France
# 4               7.0              3.0          Paraguay       H       France
# 5               1.0              0.0          Paraguay       H       France
# 6               2.0              1.0          Scotland       H       France
# 7               4.0              0.0  Northern Ireland       H       France
# 8               4.0              1.0  Northern Ireland       H       France
# 9               6.0              3.0           Germany       H       France
# 10              3.0              1.0           Hungary       H       France
# 11              4.0              1.0            Kuwait       H       France
# 12              3.0              0.0      South Africa       H       France
# 13              4.0              0.0      Saudi Arabia       H       France
# 14              2.0              1.0           Denmark       H       France
# 15              2.0              1.0           Croatia       H       France
# 16              3.0              0.0          Honduras       H       France
# 17              2.0              0.0           Nigeria       H       France
# 18              0.0              3.0            France       A       France
# 19              0.0              1.0            France       A       France
# 20              0.0              1.0            France       A       France
# 21              0.0              3.0            France       A       France
# 22              2.0              5.0            France       A       France
# 23              1.0              3.0            France       A       France
# 24              0.0              2.0            France       A       France
# 25              0.0              1.0            France       A       France
# 26              0.0              1.0            France       A       France
# 27              0.0              2.0            France       A       France
# 28              1.0              1.0            Mexico       D         Draw
# 29              0.0              0.0            Mexico       D         Draw
#
#                   Win conditions      MatchID Home Team Initials  \
# 0                                      1096.0                FRA
# 1                                      1275.0                FRA
# 2                                      1146.0                FRA
# 3   France win after extra time         422.0                FRA
# 4                                      1386.0                FRA
# 5   France win after extra time        8776.0                FRA
# 6                                      1387.0                FRA
# 7                                      1385.0                FRA
# 8                                       920.0                FRA
# 9                                      1382.0                FRA
# 10                                     2344.0                FRA
# 11                                      919.0                FRA
# 12                                     8730.0                FRA
# 13                                     8745.0                FRA
# 14                                     8762.0                FRA
# 15                                     8786.0                FRA
# 16                                300186496.0                FRA
# 17                                300186462.0                FRA
# 18                                     8788.0                BRA
# 19                                 97410060.0                BRA
# 20                                      767.0                AUT
# 21                                      567.0                HUN
# 22                                300186514.0                SUI
# 23                                 97410056.0                ESP
# 24                                      568.0                ITA
# 25                                 97410062.0                POR
# 26                                      468.0                CAN
# 27                                 97410045.0                TOG
# 28                                     1650.0                FRA
# 29                                     1689.0                URU
#
#    Away Team Initials  City Temperature  Home Team Average Temperature  \
# 0                 MEX              11.0                           13.0
# 1                 MEX              23.0                           13.0
# 2                 BEL              25.0                           13.0
# 3                 BEL              24.0                           13.0
# 4                 PAR              29.0                           13.0
# 5                 PAR              22.0                           13.0
# 6                 SCO              22.0                           13.0
# 7                 NIR              29.0                           13.0
# 8                 NIR              34.0                           13.0
# 9                 FRG              21.0                           13.0
# 10                HUN              12.0                           13.0
# 11                KUW              32.0                           13.0
# 12                RSA              25.0                           13.0
# 13                KSA              22.0                           13.0
# 14                DEN              26.0                           13.0
# 15                CRO              22.0                           13.0
# 16                HON              21.0                           13.0
# 17                NGA              28.0                           13.0
# 18                FRA              22.0                           25.0
# 19                FRA              23.0                           25.0
# 20                FRA              34.0                            7.0
# 21                FRA              28.0                           11.0
# 22                FRA              25.0                            8.0
# 23                FRA              21.0                           14.0
# 24                FRA              25.0                           13.0
# 25                FRA              20.0                           15.0
# 26                FRA              28.0                           -3.0
# 27                FRA              24.0                           27.0
# 28                MEX              24.0                           13.0
# 29                MEX              24.0                           17.0
#
#     Away Team Average Temperature  Winning Team Average Temperature
# 0                           21.00                              13.0
# 1                           21.00                              13.0
# 2                           10.00                              13.0
# 3                           10.00                              13.0
# 4                           23.00                              13.0
# 5                           23.00                              13.0
# 6                            8.45                              13.0
# 7                            9.30                              13.0
# 8                            9.30                              13.0
# 9                            9.00                              13.0
# 10                          11.00                              13.0
# 11                          26.00                              13.0
# 12                          17.00                              13.0
# 13                          26.00                              13.0
# 14                         -16.00                              13.0
# 15                          12.00                              13.0
# 16                          25.00                              13.0
# 17                          27.00                              13.0
# 18                          13.00                              13.0
# 19                          13.00                              13.0
# 20                          13.00                              13.0
# 21                          13.00                              13.0
# 22                          13.00                              13.0
# 23                          13.00                              13.0
# 24                          13.00                              13.0
# 25                          13.00                              13.0
# 26                          13.00                              13.0
# 27                          13.00                              13.0
# 28                          21.00                               NaN
# 29                          21.00                               NaN

# %%
unique_countries_home=WC_df['Home Team Name']
unique_countries_home
# Out:
# 0      France
# 1      France
# 2      France
# 3      France
# 4      France
#         ...
# 853       NaN
# 854       NaN
# 855       NaN
# 856       NaN
# 857       NaN
# Name: Home Team Name, Length: 858, dtype: object

# %%
unique_countries_away=WC_df['Away Team Name']
unique_countries_away
# Out:
# 0        Mexico
# 1        Mexico
# 2       Belgium
# 3       Belgium
# 4      Paraguay
#          ...
# 853         NaN
# 854         NaN
# 855         NaN
# 856         NaN
# 857         NaN
# Name: Away Team Name, Length: 858, dtype: object

# %%
home_team_points=pd.DataFrame({'Countries':WC_df['Home Team Name'],
                         'Number of Wins':[1 if i=='H' else 0 if i=='D' else 0 for i in WC_df['Results']],
                         'Number of Losses':[1 if i=='A' else 0 if i=='D' else 0 for i in WC_df['Results']],
                         'Number of Draws':[0 if i=='H' else 1 if i=='D' else 0 for i in WC_df['Results']],      
                         'Points':[2 if i=='H' else 1 if i=='D' else 0 for i in WC_df['Results']]})



away_team_points=pd.DataFrame({'Countries':WC_df['Away Team Name'],
                         'Number of Wins':[1 if i=='A' else 0 if i=='D' else 0 for i in WC_df['Results']],
                         'Number of Losses':[1 if i=='H' else 0 if i=='D' else 0 for i in WC_df['Results']],
                         'Number of Draws':[0 if i=='H' else 1 if i=='D' else 0 for i in WC_df['Results']],
                         'Points':[2 if i=='A' else 1 if i=='D' else 0 for i in WC_df['Results']]})

team_points=home_team_points.append(away_team_points).groupby('Countries').sum()

team_points
# Out:
#                       Number of Wins  Number of Losses  Number of Draws  \
# Countries
# Algeria                            3                 7                3
# Angola                             0                 1                2
# Argentina                         42                21               14
# Australia                          2                 8                3
# Austria                           12                13                4
# ...                              ...               ...              ...
# United Arab Emirates               0                 3                0
# Uruguay                           20                19               12
# Wales                              1                 1                3
# Yugoslavia                        16                13                8
# Zaire                              0                 3                0
#
#                       Points
# Countries
# Algeria                    9
# Angola                     2
# Argentina                 98
# Australia                  7
# Austria                   28
# ...                      ...
# United Arab Emirates       0
# Uruguay                   52
# Wales                      5
# Yugoslavia                40
# Zaire                      0
#
# [76 rows x 4 columns]

# %%
games_played=team_points['Number of Wins']+team_points['Number of Losses']+team_points['Number of Draws']
team_points['Number of Games Played'] = games_played
team_points=team_points[['Number of Games Played','Number of Wins','Number of Losses','Number of Draws','Points']]
team_points
# Out:
#                       Number of Games Played  Number of Wins  \
# Countries
# Algeria                                   13               3
# Angola                                     3               0
# Argentina                                 77              42
# Australia                                 13               2
# Austria                                   29              12
# ...                                      ...             ...
# United Arab Emirates                       3               0
# Uruguay                                   51              20
# Wales                                      5               1
# Yugoslavia                                37              16
# Zaire                                      3               0
#
#                       Number of Losses  Number of Draws  Points
# Countries
# Algeria                              7                3       9
# Angola                               1                2       2
# Argentina                           21               14      98
# Australia                            8                3       7
# Austria                             13                4      28
# ...                                ...              ...     ...
# United Arab Emirates                 3                0       0
# Uruguay                             19               12      52
# Wales                                1                3       5
# Yugoslavia                          13                8      40
# Zaire                                3                0       0
#
# [76 rows x 5 columns]

# %%
team_points.sort_values(by=['Points'], ascending=False).head(30)
# Out:
#                 Number of Games Played  Number of Wins  Number of Losses  \
# Countries
# Germany                            112              68                22
# Brazil                             104              70                17
# Italy                               83              45                17
# Argentina                           77              42                21
# England                             62              26                16
# Spain                               59              29                18
# France                              59              28                19
# Netherlands                         50              27                11
# Uruguay                             51              20                19
# Sweden                              46              16                17
# Russia                              40              17                15
# Mexico                              53              14                25
# Yugoslavia                          37              16                13
# Belgium                             41              14                18
# Poland                              31              15                11
# Hungary                             32              15                14
# Portugal                            26              13                 9
# Czech Republic                      33              12                16
# Chile                               33              11                15
# Switzerland                         33              11                16
# Austria                             29              12                13
# Paraguay                            27               7                10
# USA                                 33               8                19
# Korea Republic                      38               6                22
# Romania                             21               8                 8
# Denmark                             16               8                 6
# Croatia                             16               7                 7
# Colombia                            18               7                 9
# Scotland                            23               4                12
# Cameroon                            23               4                12
#
#                 Number of Draws  Points
# Countries
# Germany                      22     158
# Brazil                       17     157
# Italy                        21     111
# Argentina                    14      98
# England                      20      72
# Spain                        12      70
# France                       12      68
# Netherlands                  12      66
# Uruguay                      12      52
# Sweden                       13      45
# Russia                        8      42
# Mexico                       14      42
# Yugoslavia                    8      40
# Belgium                       9      37
# Poland                        5      35
# Hungary                       3      33
# Portugal                      4      30
# Czech Republic                5      29
# Chile                         7      29
# Switzerland                   6      28
# Austria                       4      28
# Paraguay                     10      24
# USA                           6      22
# Korea Republic               10      22
# Romania                       5      21
# Denmark                       2      18
# Croatia                       2      16
# Colombia                      2      16
# Scotland                      7      15
# Cameroon                      7      15

# %%
team_points.plot(kind="bar", figsize=(15,5), legend=False, y='Points')

#labels
plt.title("Points per Team")
plt.ylabel("Number Points")
# Out:
# Text(0, 0.5, 'Number Points')

# %%
best_team_points=team_points.nlargest(10, ['Points'])
best_team_points
# Out:
#              Number of Games Played  Number of Wins  Number of Losses  \
# Countries
# Germany                         112              68                22
# Brazil                          104              70                17
# Italy                            83              45                17
# Argentina                        77              42                21
# England                          62              26                16
# Spain                            59              29                18
# France                           59              28                19
# Netherlands                      50              27                11
# Uruguay                          51              20                19
# Sweden                           46              16                17
#
#              Number of Draws  Points
# Countries
# Germany                   22     158
# Brazil                    17     157
# Italy                     21     111
# Argentina                 14      98
# England                   20      72
# Spain                     12      70
# France                    12      68
# Netherlands               12      66
# Uruguay                   12      52
# Sweden                    13      45

# %%
best_team_points.plot(kind="bar", figsize=(15,5), legend=False, y='Points')

plt.ylim(50, 165)
#labels
plt.title("Top 10 Teams")
plt.ylabel("Number Points")
# Out:
# Text(0, 0.5, 'Number Points')

# %%
team_points.to_csv("Team_Points.csv",
                  encoding="utf-8", index=True, header=True)

# %%
home_team_delta=abs((WC_df['Home Team Average Temperature']-WC_df['City Temperature']))
away_team_delta=abs((WC_df['Away Team Average Temperature']-WC_df['City Temperature']))
winning_team_delta=abs((WC_df['Winning Team Average Temperature']-WC_df['City Temperature']))
delta_table = pd.DataFrame({"Home Team Name":WC_df['Home Team Name'],
                                    "Away Team Name":WC_df['Away Team Name'],
                                    "Winning Team":WC_df['Winning Team'],
                                    "Winning Team Temperature":WC_df['Winning Team Average Temperature'],
                                    "Host City":WC_df['City'],
                                    "Host City Temperature":WC_df['City Temperature'],
                                    "Home Team Average Temperature":WC_df['Home Team Average Temperature'],
                                    "Away Team Average Temperature":WC_df['Away Team Average Temperature'],
                                    "Home Team Delta":home_team_delta,
                                    "Away Team Delta":away_team_delta,
                                    "Winning Team Delta":winning_team_delta
                           })
delta_table.head(20)
# Out:
#    Home Team Name    Away Team Name Winning Team  Winning Team Temperature  \
# 0          France            Mexico       France                      13.0
# 1          France            Mexico       France                      13.0
# 2          France           Belgium       France                      13.0
# 3          France           Belgium       France                      13.0
# 4          France          Paraguay       France                      13.0
# 5          France          Paraguay       France                      13.0
# 6          France          Scotland       France                      13.0
# 7          France  Northern Ireland       France                      13.0
# 8          France  Northern Ireland       France                      13.0
# 9          France           Germany       France                      13.0
# 10         France           Hungary       France                      13.0
# 11         France            Kuwait       France                      13.0
# 12         France      South Africa       France                      13.0
# 13         France      Saudi Arabia       France                      13.0
# 14         France           Denmark       France                      13.0
# 15         France           Croatia       France                      13.0
# 16         France          Honduras       France                      13.0
# 17         France           Nigeria       France                      13.0
# 18         Brazil            France       France                      13.0
# 19         Brazil            France       France                      13.0
#
#           Host City  Host City Temperature  Home Team Average Temperature  \
# 0       Montevideo                    11.0                           13.0
# 1           Geneva                    23.0                           13.0
# 2         Colombes                    25.0                           13.0
# 3           Puebla                    24.0                           13.0
# 4       Norrk�Ping                    29.0                           13.0
# 5             Lens                    22.0                           13.0
# 6           Orebro                    22.0                           13.0
# 7       Norrk�Ping                    29.0                           13.0
# 8           Madrid                    34.0                           13.0
# 9       Gothenburg                    21.0                           13.0
# 10   Mar Del Plata                    12.0                           13.0
# 11      Valladolid                    32.0                           13.0
# 12      Marseilles                    25.0                           13.0
# 13     Saint-Denis                    22.0                           13.0
# 14            Lyon                    26.0                           13.0
# 15     Saint-Denis                    22.0                           13.0
# 16    Porto Alegre                    21.0                           13.0
# 17        Brasilia                    28.0                           13.0
# 18     Saint-Denis                    22.0                           25.0
# 19  Frankfurt/Main                    23.0                           25.0
#
#     Away Team Average Temperature  Home Team Delta  Away Team Delta  \
# 0                           21.00              2.0            10.00
# 1                           21.00             10.0             2.00
# 2                           10.00             12.0            15.00
# 3                           10.00             11.0            14.00
# 4                           23.00             16.0             6.00
# 5                           23.00              9.0             1.00
# 6                            8.45              9.0            13.55
# 7                            9.30             16.0            19.70
# 8                            9.30             21.0            24.70
# 9                            9.00              8.0            12.00
# 10                          11.00              1.0             1.00
# 11                          26.00             19.0             6.00
# 12                          17.00             12.0             8.00
# 13                          26.00              9.0             4.00
# 14                         -16.00             13.0            42.00
# 15                          12.00              9.0            10.00
# 16                          25.00              8.0             4.00
# 17                          27.00             15.0             1.00
# 18                          13.00              3.0             9.00
# 19                          13.00              2.0            10.00
#
#     Winning Team Delta
# 0                  2.0
# 1                 10.0
# 2                 12.0
# 3                 11.0
# 4                 16.0
# 5                  9.0
# 6                  9.0
# 7                 16.0
# 8                 21.0
# 9                  8.0
# 10                 1.0
# 11                19.0
# 12                12.0
# 13                 9.0
# 14                13.0
# 15                 9.0
# 16                 8.0
# 17                15.0
# 18                 9.0
# 19                10.0

# %%
x_axis
# Out:
# Winning Team
# Algeria                  1.333333
# Angola                        NaN
# Argentina                8.666667
# Australia                1.000000
# Austria                 16.583333
#                           ...
# United Arab Emirates          NaN
# Uruguay                  7.200000
# Wales                   12.550000
# Yugoslavia              14.037500
# Zaire                         NaN
# Name: Winning Team Delta, Length: 77, dtype: float64

# %%
#calculations for x-axis
TempMean=delta_table.groupby(["Winning Team"])["Winning Team Delta"].mean()
#calculations for y-axis

#******Total Point Index - Total points divided by Number of games played *************
totalPoints= team_points['Points']/team_points['Number of Games Played']

# %%
scatter_table=pd.DataFrame({'Temp':TempMean,'Points':totalPoints}).dropna()
scatter_table.head()
# Out:
#                 Temp    Points
# Algeria     1.333333  0.692308
# Argentina   8.666667  1.272727
# Australia   1.000000  0.538462
# Austria    16.583333  0.965517
# Belgium    17.714286  0.902439

# %%
#calculations for x-axis
x_axis=scatter_table["Temp"]
#calculations for y-axis
y_axis=scatter_table["Points"]
#scatter plot
plt.scatter(x_axis, y_axis, marker="o", color="blue")

#labels
plt.title("Points vs Mean Delta Temperature")
plt.xlabel("Mean Delta Temperature")
plt.ylabel("Points")
# Out:
# Text(0, 0.5, 'Points')

# %%
#Calculation for linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Duplicate of scatter plot above
plt.scatter(x_axis, y_axis, marker="o", color="blue")

#Line plot with linear regression
plt.plot(x_axis,regress_values,"r-")

#Anotation inside the graph to show line equation including the slope of line
plt.annotate(line_eq,(20,0.5),fontsize=15,color="red")

#labels
plt.title("Points vs Mean Delta Temperature")
plt.xlabel("Mean Delta Temperature")
plt.ylabel("Points")

#show r-squared value
print(f"The r-squared is: {round(rvalue**2,3)}")
# Out:
# The r-squared is: 0.059
